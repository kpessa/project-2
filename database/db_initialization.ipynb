# %%
# Dependancies
import pandas as pd
import os
from sqlalchemy import create_engine

# Import relevant files
# File load
file1 = os.path.join('..', 'resources', '6-all-data.csv')
file2 = os.path.join('..', 'resources', '7-fl-data.csv')

# File read
complete_df = pd.read_csv(file1)
fl_df = pd.read_csv(file2)

# %%
# Sql lite file name
sql_lite = "sqlite:///covid_factors_database.sqlite"

# %%
#  Create engine
engine = create_engine(sql_lite)

# %%
complete_df.to_sql(name="complete_data", con=engine, if_exists="replace", index=False)
fl_df.to_sql(name="florida_data", con=engine, if_exists="replace", index=False)

# %%
engine.table_names()
# Out:
# ['complete_data', 'florida_data']

# %%
# Testing
df = pd.read_sql_query('SELECT * FROM complete_data', con=engine)
df
# Out:
#           date    state abbr     county   fips population  ccvi score  cases  \
# 0    9/30/2020  Alabama   AL    Autauga   1001     55,869       0.804   1791
# 1    9/30/2020  Alabama   AL    Barbour   1005     24,686       0.986    896
# 2    9/30/2020  Alabama   AL       Bibb   1007     22,394       0.803    664
# 3    9/30/2020  Alabama   AL    Bullock   1011     10,101       0.947    610
# 4    9/30/2020  Alabama   AL     Butler   1013     19,448       0.855    917
# ..         ...      ...  ...        ...    ...        ...         ...    ...
# 281  9/30/2020  Georgia   GA  Whitfield  13313    104,628       0.649   4625
# 282  9/30/2020  Georgia   GA     Wilcox  13315      8,635       0.937    247
# 283  9/30/2020  Georgia   GA     Wilkes  13317      9,777       0.935    268
# 284  9/30/2020  Georgia   GA      Worth  13321     20,247       0.898    535
# 285  9/30/2020   Hawaii   HI     Hawaii  15001    201,513       0.397    739
#
#      case rate  deaths  death rate median income 2018  uninsured percent  \
# 0      0.01791      27     0.00027             59,338               0.09
# 1      0.00896       7     0.00007             34,382               0.12
# 2      0.00664      11     0.00011             46,064               0.10
# 3      0.00610      15     0.00015             29,267               0.11
# 4      0.00917      40     0.00040             37,365               0.11
# ..         ...     ...         ...                ...                ...
# 281    0.04625      60     0.00060             47,074               0.23
# 282    0.00247      20     0.00020             35,961               0.17
# 283    0.00268       5     0.00005             39,361               0.18
# 284    0.00535      30     0.00030             48,708               0.17
# 285    0.00739      15     0.00015             56,383               0.06
#
#      fair or poor health percent  socioeconomic status  \
# 0                           0.21                 0.357
# 1                           0.30                 0.973
# 2                           0.19                 0.746
# 3                           0.31                 0.947
# 4                           0.28                 0.812
# ..                           ...                   ...
# 281                         0.23                 0.814
# 282                         0.22                 0.881
# 283                         0.24                 0.731
# 284                         0.20                 0.811
# 285                         0.14                 0.384
#
#      household composition and disability  minority status and language  \
# 0                                   0.566                         0.592
# 1                                   0.839                         0.897
# 2                                   0.249                         0.443
# 3                                   0.367                         0.814
# 4                                   0.728                         0.567
# ..                                    ...                           ...
# 281                                 0.289                         0.924
# 282                                 0.200                         0.790
# 283                                 0.831                         0.849
# 284                                 0.918                         0.500
# 285                                 0.403                         0.943
#
#      housing type and transportation  epidemiological factors  \
# 0                              0.314                    0.833
# 1                              0.640                    0.778
# 2                              0.743                    0.726
# 3                              0.454                    0.952
# 4                              0.582                    0.823
# ..                               ...                      ...
# 281                            0.787                    0.142
# 282                            0.809                    0.752
# 283                            0.402                    0.897
# 284                            0.399                    0.685
# 285                            0.343                    0.259
#
#      healthcare system factors
# 0                        0.976
# 1                        0.852
# 2                        0.972
# 3                        0.861
# 4                        0.690
# ..                         ...
# 281                      0.521
# 282                      0.973
# 283                      0.857
# 284                      0.943
# 285                      0.261
#
# [286 rows x 20 columns]

# %%
# Testing
df = pd.read_sql_query('SELECT * FROM complete_data', con=engine)
df
# Out:
#           date    state abbr     county   fips population  ccvi score  cases  \
# 0    9/30/2020  Alabama   AL    Autauga   1001     55,869       0.804   1791
# 1    9/30/2020  Alabama   AL    Barbour   1005     24,686       0.986    896
# 2    9/30/2020  Alabama   AL       Bibb   1007     22,394       0.803    664
# 3    9/30/2020  Alabama   AL    Bullock   1011     10,101       0.947    610
# 4    9/30/2020  Alabama   AL     Butler   1013     19,448       0.855    917
# ..         ...      ...  ...        ...    ...        ...         ...    ...
# 281  9/30/2020  Georgia   GA  Whitfield  13313    104,628       0.649   4625
# 282  9/30/2020  Georgia   GA     Wilcox  13315      8,635       0.937    247
# 283  9/30/2020  Georgia   GA     Wilkes  13317      9,777       0.935    268
# 284  9/30/2020  Georgia   GA      Worth  13321     20,247       0.898    535
# 285  9/30/2020   Hawaii   HI     Hawaii  15001    201,513       0.397    739
#
#      case rate  deaths  death rate median income 2018  uninsured percent  \
# 0      0.01791      27     0.00027             59,338               0.09
# 1      0.00896       7     0.00007             34,382               0.12
# 2      0.00664      11     0.00011             46,064               0.10
# 3      0.00610      15     0.00015             29,267               0.11
# 4      0.00917      40     0.00040             37,365               0.11
# ..         ...     ...         ...                ...                ...
# 281    0.04625      60     0.00060             47,074               0.23
# 282    0.00247      20     0.00020             35,961               0.17
# 283    0.00268       5     0.00005             39,361               0.18
# 284    0.00535      30     0.00030             48,708               0.17
# 285    0.00739      15     0.00015             56,383               0.06
#
#      fair or poor health percent  socioeconomic status  \
# 0                           0.21                 0.357
# 1                           0.30                 0.973
# 2                           0.19                 0.746
# 3                           0.31                 0.947
# 4                           0.28                 0.812
# ..                           ...                   ...
# 281                         0.23                 0.814
# 282                         0.22                 0.881
# 283                         0.24                 0.731
# 284                         0.20                 0.811
# 285                         0.14                 0.384
#
#      household composition and disability  minority status and language  \
# 0                                   0.566                         0.592
# 1                                   0.839                         0.897
# 2                                   0.249                         0.443
# 3                                   0.367                         0.814
# 4                                   0.728                         0.567
# ..                                    ...                           ...
# 281                                 0.289                         0.924
# 282                                 0.200                         0.790
# 283                                 0.831                         0.849
# 284                                 0.918                         0.500
# 285                                 0.403                         0.943
#
#      housing type and transportation  epidemiological factors  \
# 0                              0.314                    0.833
# 1                              0.640                    0.778
# 2                              0.743                    0.726
# 3                              0.454                    0.952
# 4                              0.582                    0.823
# ..                               ...                      ...
# 281                            0.787                    0.142
# 282                            0.809                    0.752
# 283                            0.402                    0.897
# 284                            0.399                    0.685
# 285                            0.343                    0.259
#
#      healthcare system factors
# 0                        0.976
# 1                        0.852
# 2                        0.972
# 3                        0.861
# 4                        0.690
# ..                         ...
# 281                      0.521
# 282                      0.973
# 283                      0.857
# 284                      0.943
# 285                      0.261
#
# [286 rows x 20 columns]
